# %%
from calciumflexanalysis import calcium_flex as cal

# %%
# text file to be read in
datafile = '14052019 C5sYFP2 IBP21 inhib 300nM to 0.3 nM.txt' 

# plate map csv file updated by user
mapcsv = 'shortmap_example.csv' 

flex = cal.CaFlexAnalysis(raw_data = datafile, plate_map_file = mapcsv)

flex.plate_map
# Out:
#         Well ID           Type Contents Compound Protein  Concentration  \
# Well ID
# A1           A1  assay control  EA+DMSO      NaN      EA            NaN
# A2           A2  assay control  EA+DMSO      NaN      EA            NaN
# A3           A3  assay control  EA+DMSO      NaN      EA            NaN
# A4           A4  assay control  EA+DMSO      NaN      EA            NaN
# A5           A5  assay control  EA+DMSO      NaN      EA            NaN
# ...         ...            ...      ...      ...     ...            ...
# H8           H8          empty      NaN      NaN     NaN            NaN
# H9           H9          empty      NaN      NaN     NaN            NaN
# H10         H10          empty      NaN      NaN     NaN            NaN
# H11         H11          empty      NaN      NaN     NaN            NaN
# H12         H12          empty      NaN      NaN     NaN            NaN
#
#         Concentration Units Row  Column  Valid
# Well ID
# ...

# %%
flex.see_plate()
# flex.see_plate(labelby = 'Contents', colorby = 'Concentration')

# %%
flex.visualise_assay(colorby = 'Concentration', labelby = 'Contents')

# %%
invalid = "H2", "E5", "A2"

# flex.see_wells(invalid)

flex.invalidate_wells(invalid)

flex.visualise_assay()

flex.invalidate_rows('B')
flex.invalidate_cols(6)

flex.see_plate(colormap = 'summer')
# Out:
# C:\Users\Lawrence\PROJECT FOLDER\platemapping\plate_map.py:271: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(grid[(ord(platemap['Row'].iloc[i].lower())-96), ((platemap['Column'].iloc[i]))])
